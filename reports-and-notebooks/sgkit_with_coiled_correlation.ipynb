# %%
from sgkit.distance.api import pairwise_distance_blocks, pairwise_distance_blockwise
import dask.array as da

from dask.distributed import Client, performance_report, get_task_stream
from dask.diagnostics import ProgressBar, ResourceProfiler
from bokeh.io import output_notebook

import numpy as np
import coiled
import fsspec, zarr

# %%
coiled.__version__
# Out:
# '0.0.35'

# %%
import dask
dask.__version__
# Out:
# '2.30.0'

# %%
# !pwd
# Out:
# /Users/aktech/dev/sgkit

# %%
# env_name = "sgkit-blockwise-new"
env_name = "pairwise-comparison-clean"

# %%
# %%time
coiled.create_software_environment(
    name=env_name,
    conda="environment.yml",
)
# Out:
# Updating software environment...
# Solving conda environment...
# Conda environment solved!
# Building Docker image
# (this takes a few minutes)
# STEP 1: FROM coiled/default:sha-9aa53a2
# STEP 2: COPY environment.yml environment.yml
# --> fc9246144e4
# STEP 3: RUN conda env update -n coiled -f environment.yml     && rm environment.yml     && conda clean --all -y     && echo "conda activate coiled" >> ~/.bashrc
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# chardet-3.0.4        | 170 KB    | ########## | 100%
# libsodium-1.0.18     | 366 KB    | ########## | 100%
# typing_extensions-3. | 25 KB     | ########## | 100%
# rsa-4.7              | 27 KB     | ########## | 100%
# pyopenssl-20.0.1     | 48 KB     | ########## | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ########## | 100%
# six-1.15.0           | 14 KB     | ########## | 100%
# bleach-3.3.0         | 111 KB    | ########## | 100%
# partd-1.1.0          | 17 KB     | ########## | 100%
# async-timeout-3.0.1  | 11 KB     | ########## | 100%
# multidict-5.1.0      | 68 KB     | ########## | 100%
# zipp-3.4.0           | 11 KB     | ########## | 100%
# certifi-2020.12.5    | 143 KB    | ########## | 100%
# cloudpickle-1.6.0    | 22 KB     | ########## | 100%
# urllib3-1.26.3       | 99 KB     | ########## | 100%
# prompt-toolkit-3.0.1 | 239 KB    | ########## | 100%
# traitlets-5.0.5      | 81 KB     | ########## | 100%
# gcsfs-0.7.1          | 22 KB     | ########## | 100%
# dask-ml-1.8.0        | 100 KB    | ########## | 100%
# pycparser-2.20       | 94 KB     | ########## | 100%
# pandocfilters-1.4.2  | 9 KB      | ########## | 100%
# openssl-1.1.1i       | 2.1 MB    | ########## | 100%
# ipykernel-5.4.2      | 165 KB    | ########## | 100%
# pickleshare-0.7.5    | 9 KB      | ########## | 100%
# xarray-0.16.2        | 546 KB    | ########## | 100%
# monotonic-1.5        | 9 KB      | ########## | 100%
# google-auth-1.24.0   | 62 KB     | ########## | 100%
# numpy-1.20.0         | 5.8 MB    | ########## | 100%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
# attrs-20.3.0         | 41 KB     | ########## | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
# readline-8.0         | 281 KB    | ########## | 100%
# pyparsing-2.4.7      | 60 KB     | ########## | 100%
# distributed-2021.1.1 | 1.1 MB    | ########## | 100%
# nbclient-0.5.1       | 60 KB     | ########## | 100%
# toolz-0.11.1         | 46 KB     | ########## | 100%
# sniffio-1.2.0        | 15 KB     | ########## | 100%
# sqlite-3.34.0        | 1.4 MB    | ########## | 100%
# webencodings-0.5.1   | 12 KB     | ########## | 100%
# cryptography-3.3.1   | 626 KB    | ########## | 100%
# ipython-7.20.0       | 1.1 MB    | ########## | 100%
# sortedcontainers-2.3 | 26 KB     | ########## | 100%
# backcall-0.2.0       | 13 KB     | ########## | 100%
# dask-2021.1.1        | 4 KB      | ########## | 100%
# libffi-3.2.1         | 47 KB     | ########## | 100%
# setuptools-49.6.0    | 929 KB    | ########## | 100%
# typing-extensions-3. | 8 KB      | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# importlib_metadata-3 | 3 KB      | ########## | 100%
# nbclassic-0.2.6      | 17 KB     | ########## | 100%
# s3fs-0.5.2           | 23 KB     | ########## | 100%
# aioitertools-0.7.1   | 19 KB     | ########## | 100%
# jupyterlab_pygments- | 8 KB      | ########## | 100%
# idna-2.10            | 52 KB     | ########## | 100%
# ptyprocess-0.7.0     | 16 KB     | ########## | 100%
# pysocks-1.7.1        | 27 KB     | ########## | 100%
# s3transfer-0.3.4     | 51 KB     | ########## | 100%
# dask-glm-0.2.0       | 14 KB     | ########## | 100%
# zstd-1.4.8           | 702 KB    | ########## | 100%
# fasteners-0.14.1     | 18 KB     | ########## | 100%
# joblib-1.0.0         | 206 KB    | ########## | 100%
# llvmlite-0.35.0      | 239 KB    | ########## | 100%
# oauthlib-3.0.1       | 82 KB     | ########## | 100%
# libopenblas-0.3.12   | 8.9 MB    | ########## | 100%
# packaging-20.8       | 34 KB     | ########## | 100%
# yarl-1.6.3           | 143 KB    | ########## | 100%
# zarr-2.6.1           | 100 KB    | ########## | 100%
# bokeh-2.2.3          | 7.0 MB    | ########## | 100%
# multipledispatch-0.6 | 12 KB     | ########## | 100%
# tornado-6.1          | 649 KB    | ########## | 100%
# psutil-5.8.0         | 342 KB    | ########## | 100%
# pandas-1.2.1         | 12.0 MB   | ########## | 100%
# json5-0.9.5          | 20 KB     | ########## | 100%
# prometheus_client-0. | 44 KB     | ########## | 100%
# jupyterlab_server-2. | 37 KB     | ########## | 100%
# python-3.8.0         | 38.4 MB   | ########## | 100%
# libgomp-9.3.0        | 376 KB    | ########## | 100%
# dask-core-2021.1.1   | 674 KB    | ########## | 100%
# jsonschema-3.2.0     | 45 KB     | ########## | 100%
# cachetools-4.2.1     | 13 KB     | ########## | 100%
# parso-0.8.1          | 67 KB     | ########## | 100%
# libwebp-base-1.2.0   | 808 KB    | ########## | 100%
# mistune-0.8.4        | 54 KB     | ########## | 100%
# pyyaml-5.4.1         | 192 KB    | ########## | 100%
# coiled-0.0.35        | 43 KB     | ########## | 100%
# click-7.1.2          | 64 KB     | ########## | 100%
# msgpack-python-1.0.2 | 92 KB     | ########## | 100%
# zlib-1.2.11          | 106 KB    | ########## | 100%
# pexpect-4.8.0        | 47 KB     | ########## | 100%
# aiohttp-3.7.3        | 625 KB    | ########## | 100%
# brotlipy-0.7.0       | 341 KB    | ########## | 100%
# fsspec-0.8.5         | 69 KB     | ########## | 100%
# send2trash-1.5.0     | 12 KB     | ########## | 100%
# jupyterlab-3.0.6     | 5.7 MB    | ########## | 100%
# nest-asyncio-1.4.3   | 9 KB      | ########## | 100%
# tblib-1.6.0          | 14 KB     | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
# nbformat-5.1.2       | 66 KB     | ########## | 100%
# jpeg-9d              | 264 KB    | ########## | 100%
# python_abi-3.8       | 4 KB      | ########## | 100%
# requests-2.25.1      | 51 KB     | ########## | 100%
# scipy-1.6.0          | 20.6 MB   | ########## | 100%
# jupyter_client-6.1.1 | 76 KB     | ########## | 100%
# terminado-0.9.2      | 26 KB     | ########## | 100%
# backports-1.0        | 4 KB      | ########## | 100%
# pytz-2021.1          | 239 KB    | ########## | 100%
# pyzmq-22.0.1         | 530 KB    | ########## | 100%
# decorator-4.4.2      | 11 KB     | ########## | 100%
# lcms2-2.11           | 434 KB    | ########## | 100%
# markupsafe-1.1.1     | 27 KB     | ########## | 100%
# threadpoolctl-2.1.0  | 15 KB     | ########## | 100%
# heapdict-1.0.1       | 7 KB      | ########## | 100%
# locket-0.2.0         | 6 KB      | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# babel-2.9.0          | 6.2 MB    | ########## | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ########## | 100%
# pandoc-2.11.4        | 17.9 MB   | ########## | 100%
# freetype-2.10.4      | 890 KB    | ########## | 100%
# libcblas-3.9.0       | 11 KB     | ########## | 100%
# zeromq-4.3.3         | 288 KB    | ########## | 100%
# importlib-metadata-3 | 20 KB     | ########## | 100%
# jmespath-0.10.0      | 21 KB     | ########## | 100%
# botocore-1.19.52     | 4.4 MB    | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# pillow-8.1.0         | 674 KB    | ########## | 100%
# asciitree-0.3.3      | 6 KB      | ########## | 100%
# aiobotocore-1.2.0    | 39 KB     | ########## | 100%
# nbconvert-6.0.7      | 546 KB    | ########## | 100%
# argon2-cffi-20.1.0   | 48 KB     | ########## | 100%
# wheel-0.36.2         | 31 KB     | ########## | 100%
# google-auth-oauthlib | 19 KB     | ########## | 100%
# scikit-learn-0.24.1  | 7.6 MB    | ########## | 100%
# notebook-6.2.0       | 6.3 MB    | ########## | 100%
# ca-certificates-2020 | 137 KB    | ########## | 100%
# ncurses-6.2          | 985 KB    | ########## | 100%
# olefile-0.46         | 32 KB     | ########## | 100%
# numcodecs-0.7.3      | 1000 KB   | ########## | 100%
# entrypoints-0.3      | 8 KB      | ########## | 100%
# defusedxml-0.6.0     | 22 KB     | ########## | 100%
# ipython_genutils-0.2 | 21 KB     | ########## | 100%
# jinja2-2.11.3        | 93 KB     | ########## | 100%
# numba-0.52.0         | 3.6 MB    | ########## | 100%
# pip-21.0.1           | 1.1 MB    | ########## | 100%
# pygments-2.7.4       | 708 KB    | ########## | 100%
# anyio-2.0.2          | 110 KB    | ########## | 100%
# boto3-1.16.52        | 70 KB     | ########## | 100%
# cffi-1.14.4          | 226 KB    | ########## | 100%
# cytoolz-0.11.0       | 420 KB    | ########## | 100%
# yaml-0.2.5           | 82 KB     | ########## | 100%
# testpath-0.4.4       | 85 KB     | ########## | 100%
# wrapt-1.12.1         | 47 KB     | ########## | 100%
# zict-2.0.0           | 10 KB     | ########## | 100%
# pyjwt-2.0.1          | 17 KB     | ########## | 100%
# jupyter_server-1.2.2 | 244 KB    | ########## | 100%
# liblapack-3.9.0      | 11 KB     | ########## | 100%
# libtiff-4.2.0        | 633 KB    | ########## | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ########## | 100%
# ld_impl_linux-64-2.3 | 618 KB    | ########## | 100%
# libpng-1.6.37        | 306 KB    | ########## | 100%
# blinker-1.4          | 13 KB     | ########## | 100%
# pyrsistent-0.17.3    | 90 KB     | ########## | 100%
# libblas-3.9.0        | 11 KB     | ########## | 100%
# requests-oauthlib-1. | 21 KB     | ########## | 100%
# wcwidth-0.2.5        | 33 KB     | ########## | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
# pyasn1-0.4.8         | 53 KB     | ########## | 100%
# jedi-0.18.0          | 937 KB    | ########## | 100%
# libllvm10-10.0.1     | 26.4 MB   | ########## | 100%
# lz4-c-1.9.3          | 179 KB    | ########## | 100%
# jupyter_core-4.7.1   | 72 KB     | ########## | 100%
# backports.functools_ | 8 KB      | ########## | 100%
# async_generator-1.10 | 18 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate coiled
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Cache location: /opt/conda/pkgs
# Will remove the following tarballs:
#
# /opt/conda/pkgs
# ---------------
# chardet-3.0.4-py38h924ce5b_1008.tar.bz2      170 KB
# libsodium-1.0.18-h36c2ea0_1.tar.bz2          366 KB
# typing_extensions-3.7.4.3-py_0.tar.bz2        25 KB
# rsa-4.7-pyhd3deb0d_0.tar.bz2                  27 KB
# pyopenssl-20.0.1-pyhd8ed1ab_0.tar.bz2         48 KB
# libgfortran-ng-9.3.0-hff62375_18.tar.bz2      22 KB
# six-1.15.0-pyh9f0ad1d_0.tar.bz2               14 KB
# bleach-3.3.0-pyh44b312d_0.tar.bz2            111 KB
# partd-1.1.0-py_0.tar.bz2                      17 KB
# async-timeout-3.0.1-py_1000.tar.bz2           11 KB
# multidict-5.1.0-py38h497a2fe_1.tar.bz2        68 KB
# zipp-3.4.0-py_0.tar.bz2                       11 KB
# certifi-2020.12.5-py38h578d9bd_1.tar.bz2     143 KB
# cloudpickle-1.6.0-py_0.tar.bz2                22 KB
# urllib3-1.26.3-pyhd8ed1ab_0.tar.bz2           99 KB
# prompt-toolkit-3.0.14-pyha770c72_0.tar.bz2     239 KB
# traitlets-5.0.5-py_0.tar.bz2                  81 KB
# gcsfs-0.7.1-py_0.tar.bz2                      22 KB
# dask-ml-1.8.0-pyhd8ed1ab_0.tar.bz2           100 KB
# pycparser-2.20-pyh9f0ad1d_2.tar.bz2           94 KB
# pandocfilters-1.4.2-py_1.tar.bz2               9 KB
# openssl-1.1.1i-h7f98852_0.tar.bz2            2.1 MB
# ipykernel-5.4.2-py38h81c977d_0.tar.bz2       165 KB
# pickleshare-0.7.5-py_1003.tar.bz2              9 KB
# xarray-0.16.2-pyhd8ed1ab_0.tar.bz2           546 KB
# monotonic-1.5-py_0.tar.bz2                     9 KB
# google-auth-1.24.0-pyhd3deb0d_0.tar.bz2       62 KB
# numpy-1.20.0-py38h18fd61f_0.tar.bz2          5.8 MB
# python-dateutil-2.8.1-py_0.tar.bz2           220 KB
# attrs-20.3.0-pyhd3deb0d_0.tar.bz2             41 KB
# libstdcxx-ng-9.3.0-h6de172a_18.tar.bz2       4.0 MB
# readline-8.0-he28a2e2_2.tar.bz2              281 KB
# pyparsing-2.4.7-pyh9f0ad1d_0.tar.bz2          60 KB
# distributed-2021.1.1-py38h578d9bd_0.tar.bz2     1.1 MB
# nbclient-0.5.1-py_0.tar.bz2                   60 KB
# toolz-0.11.1-py_0.tar.bz2                     46 KB
# sniffio-1.2.0-py38h578d9bd_1.tar.bz2          15 KB
# sqlite-3.34.0-h74cdb3f_0.tar.bz2             1.4 MB
# webencodings-0.5.1-py_1.tar.bz2               12 KB
# cryptography-3.3.1-py38h2b97feb_1.tar.bz2     626 KB
# ipython-7.20.0-py38h81c977d_0.tar.bz2        1.1 MB
# sortedcontainers-2.3.0-pyhd8ed1ab_0.tar.bz2      26 KB
# backcall-0.2.0-pyh9f0ad1d_0.tar.bz2           13 KB
# dask-2021.1.1-pyhd8ed1ab_0.tar.bz2             4 KB
# libffi-3.2.1-he1b5a44_1007.tar.bz2            47 KB
# setuptools-49.6.0-py38h578d9bd_3.tar.bz2     929 KB
# typing-extensions-3.7.4.3-0.tar.bz2            8 KB
# tk-8.6.10-h21135ba_1.tar.bz2                 3.2 MB
# importlib_metadata-3.4.0-hd8ed1ab_0.tar.bz2       3 KB
# nbclassic-0.2.6-pyhd8ed1ab_0.tar.bz2          17 KB
# s3fs-0.5.2-pyhd8ed1ab_0.tar.bz2               23 KB
# aioitertools-0.7.1-pyhd8ed1ab_0.tar.bz2       19 KB
# jupyterlab_pygments-0.1.2-pyh9f0ad1d_0.tar.bz2       8 KB
# idna-2.10-pyh9f0ad1d_0.tar.bz2                52 KB
# ptyprocess-0.7.0-pyhd3deb0d_0.tar.bz2         16 KB
# pysocks-1.7.1-py38h578d9bd_3.tar.bz2          27 KB
# s3transfer-0.3.4-pyhd8ed1ab_0.tar.bz2         51 KB
# dask-glm-0.2.0-py_1.tar.bz2                   14 KB
# zstd-1.4.8-ha95c52a_1.tar.bz2                702 KB
# fasteners-0.14.1-py_3.tar.bz2                 18 KB
# joblib-1.0.0-pyhd8ed1ab_0.tar.bz2            206 KB
# llvmlite-0.35.0-py38h4630a5e_1.tar.bz2       239 KB
# oauthlib-3.0.1-py_0.tar.bz2                   82 KB
# libopenblas-0.3.12-pthreads_h4812303_1.tar.bz2     8.9 MB
# packaging-20.8-pyhd3deb0d_0.tar.bz2           34 KB
# yarl-1.6.3-py38h497a2fe_1.tar.bz2            143 KB
# zarr-2.6.1-pyhd8ed1ab_0.tar.bz2              100 KB
# bokeh-2.2.3-py38h578d9bd_0.tar.bz2           7.0 MB
# multipledispatch-0.6.0-py_0.tar.bz2           12 KB
# tornado-6.1-py38h497a2fe_1.tar.bz2           649 KB
# psutil-5.8.0-py38h497a2fe_1.tar.bz2          342 KB
# pandas-1.2.1-py38h51da96c_0.tar.bz2         12.0 MB
# json5-0.9.5-pyh9f0ad1d_0.tar.bz2              20 KB
# prometheus_client-0.9.0-pyhd3deb0d_0.tar.bz2      44 KB
# jupyterlab_server-2.1.3-pyhd8ed1ab_0.tar.bz2      37 KB
# python-3.8.0-h357f687_5.tar.bz2             38.4 MB
# libgomp-9.3.0-h2828fa1_18.tar.bz2            376 KB
# dask-core-2021.1.1-pyhd8ed1ab_0.tar.bz2      674 KB
# jsonschema-3.2.0-py_2.tar.bz2                 45 KB
# cachetools-4.2.1-pyhd8ed1ab_0.tar.bz2         13 KB
# parso-0.8.1-pyhd8ed1ab_0.tar.bz2              67 KB
# libwebp-base-1.2.0-h7f98852_0.tar.bz2        808 KB
# mistune-0.8.4-py38h497a2fe_1003.tar.bz2       54 KB
# pyyaml-5.4.1-py38h497a2fe_0.tar.bz2          192 KB
# coiled-0.0.35-pyhd8ed1ab_0.tar.bz2            43 KB
# click-7.1.2-pyh9f0ad1d_0.tar.bz2              64 KB
# msgpack-python-1.0.2-py38h1fd1430_1.tar.bz2      92 KB
# zlib-1.2.11-h516909a_1010.tar.bz2            106 KB
# pexpect-4.8.0-pyh9f0ad1d_2.tar.bz2            47 KB
# aiohttp-3.7.3-py38h497a2fe_1.tar.bz2         625 KB
# brotlipy-0.7.0-py38h497a2fe_1001.tar.bz2     341 KB
# fsspec-0.8.5-pyhd8ed1ab_0.tar.bz2             69 KB
# send2trash-1.5.0-py_0.tar.bz2                 12 KB
# jupyterlab-3.0.6-pyhd8ed1ab_0.tar.bz2        5.7 MB
# nest-asyncio-1.4.3-pyhd8ed1ab_0.tar.bz2        9 KB
# tblib-1.6.0-py_0.tar.bz2                      14 KB
# xz-5.2.5-h516909a_1.tar.bz2                  343 KB
# nbformat-5.1.2-pyhd8ed1ab_1.tar.bz2           66 KB
# jpeg-9d-h36c2ea0_0.tar.bz2                   264 KB
# python_abi-3.8-1_cp38.tar.bz2                  4 KB
# requests-2.25.1-pyhd3deb0d_0.tar.bz2          51 KB
# scipy-1.6.0-py38hb2138dd_0.tar.bz2          20.6 MB
# jupyter_client-6.1.11-pyhd8ed1ab_1.tar.bz2      76 KB
# terminado-0.9.2-py38h578d9bd_0.tar.bz2        26 KB
# backports-1.0-py_2.tar.bz2                     4 KB
# pytz-2021.1-pyhd8ed1ab_0.tar.bz2             239 KB
# pyzmq-22.0.1-py38h3d7ac18_0.tar.bz2          530 KB
# decorator-4.4.2-py_0.tar.bz2                  11 KB
# lcms2-2.11-hcbb858e_1.tar.bz2                434 KB
# markupsafe-1.1.1-py38h497a2fe_3.tar.bz2       27 KB
# threadpoolctl-2.1.0-pyh5ca1d4c_0.tar.bz2      15 KB
# heapdict-1.0.1-py_0.tar.bz2                    7 KB
# locket-0.2.0-py_2.tar.bz2                      6 KB
# _openmp_mutex-4.5-1_gnu.tar.bz2               22 KB
# babel-2.9.0-pyhd3deb0d_0.tar.bz2             6.2 MB
# pyasn1-modules-0.2.7-py_0.tar.bz2             60 KB
# pandoc-2.11.4-h7f98852_0.tar.bz2            17.9 MB
# freetype-2.10.4-h0708190_1.tar.bz2           890 KB
# libcblas-3.9.0-7_openblas.tar.bz2             11 KB
# zeromq-4.3.3-h58526e2_3.tar.bz2              288 KB
# importlib-metadata-3.4.0-py38h578d9bd_0.tar.bz2      20 KB
# jmespath-0.10.0-pyh9f0ad1d_0.tar.bz2          21 KB
# botocore-1.19.52-pyhd8ed1ab_0.tar.bz2        4.4 MB
# _libgcc_mutex-0.1-conda_forge.tar.bz2          3 KB
# pillow-8.1.0-py38h357d4e7_1.tar.bz2          674 KB
# asciitree-0.3.3-py_2.tar.bz2                   6 KB
# aiobotocore-1.2.0-pyhd8ed1ab_0.tar.bz2        39 KB
# nbconvert-6.0.7-py38h578d9bd_3.tar.bz2       546 KB
# argon2-cffi-20.1.0-py38h497a2fe_2.tar.bz2      48 KB
# wheel-0.36.2-pyhd3deb0d_0.tar.bz2             31 KB
# google-auth-oauthlib-0.4.2-pyhd8ed1ab_0.tar.bz2      19 KB
# scikit-learn-0.24.1-py38h658cfdd_0.tar.bz2     7.6 MB
# notebook-6.2.0-py38h578d9bd_0.tar.bz2        6.3 MB
# ca-certificates-2020.12.5-ha878542_0.tar.bz2     137 KB
# ncurses-6.2-h58526e2_4.tar.bz2               985 KB
# olefile-0.46-pyh9f0ad1d_1.tar.bz2             32 KB
# numcodecs-0.7.3-py38h709712a_0.tar.bz2      1000 KB
# entrypoints-0.3-pyhd8ed1ab_1003.tar.bz2        8 KB
# defusedxml-0.6.0-py_0.tar.bz2                 22 KB
# ipython_genutils-0.2.0-py_1.tar.bz2           21 KB
# jinja2-2.11.3-pyh44b312d_0.tar.bz2            93 KB
# numba-0.52.0-py38h51da96c_0.tar.bz2          3.6 MB
# pip-21.0.1-pyhd8ed1ab_0.tar.bz2              1.1 MB
# pygments-2.7.4-pyhd8ed1ab_0.tar.bz2          708 KB
# anyio-2.0.2-py38h578d9bd_4.tar.bz2           110 KB
# boto3-1.16.52-pyhd8ed1ab_0.tar.bz2            70 KB
# cffi-1.14.4-py38ha312104_0.tar.bz2           226 KB
# cytoolz-0.11.0-py38h497a2fe_3.tar.bz2        420 KB
# yaml-0.2.5-h516909a_0.tar.bz2                 82 KB
# testpath-0.4.4-py_0.tar.bz2                   85 KB
# wrapt-1.12.1-py38h497a2fe_3.tar.bz2           47 KB
# zict-2.0.0-py_0.tar.bz2                       10 KB
# pyjwt-2.0.1-pyhd8ed1ab_0.tar.bz2              17 KB
# jupyter_server-1.2.2-py38h578d9bd_1.tar.bz2     244 KB
# liblapack-3.9.0-7_openblas.tar.bz2            11 KB
# libtiff-4.2.0-hdc55705_0.tar.bz2             633 KB
# libgfortran5-9.3.0-hff62375_18.tar.bz2       2.0 MB
# ld_impl_linux-64-2.35.1-hea4e1c9_2.tar.bz2     618 KB
# libpng-1.6.37-h21135ba_2.tar.bz2             306 KB
# blinker-1.4-py_1.tar.bz2                      13 KB
# pyrsistent-0.17.3-py38h497a2fe_2.tar.bz2      90 KB
# libblas-3.9.0-7_openblas.tar.bz2              11 KB
# requests-oauthlib-1.3.0-pyh9f0ad1d_0.tar.bz2      21 KB
# wcwidth-0.2.5-pyh9f0ad1d_2.tar.bz2            33 KB
# libgcc-ng-9.3.0-h2828fa1_18.tar.bz2          7.8 MB
# pyasn1-0.4.8-py_0.tar.bz2                     53 KB
# jedi-0.18.0-py38h578d9bd_2.tar.bz2           937 KB
# libllvm10-10.0.1-he513fc3_3.tar.bz2         26.4 MB
# lz4-c-1.9.3-h9c3ff4c_0.tar.bz2               179 KB
# jupyter_core-4.7.1-py38h578d9bd_0.tar.bz2      72 KB
# backports.functools_lru_cache-1.6.1-py_0.tar.bz2       8 KB
# async_generator-1.10-py_0.tar.bz2             18 KB
#
# ---------------------------------------------------
# Total:                                     217.6 MB
#
# Removed chardet-3.0.4-py38h924ce5b_1008.tar.bz2
# Removed libsodium-1.0.18-h36c2ea0_1.tar.bz2
# Removed typing_extensions-3.7.4.3-py_0.tar.bz2
# Removed rsa-4.7-pyhd3deb0d_0.tar.bz2
# Removed pyopenssl-20.0.1-pyhd8ed1ab_0.tar.bz2
# Removed libgfortran-ng-9.3.0-hff62375_18.tar.bz2
# Removed six-1.15.0-pyh9f0ad1d_0.tar.bz2
# Removed bleach-3.3.0-pyh44b312d_0.tar.bz2
# Removed partd-1.1.0-py_0.tar.bz2
# Removed async-timeout-3.0.1-py_1000.tar.bz2
# Removed multidict-5.1.0-py38h497a2fe_1.tar.bz2
# Removed zipp-3.4.0-py_0.tar.bz2
# Removed certifi-2020.12.5-py38h578d9bd_1.tar.bz2
# Removed cloudpickle-1.6.0-py_0.tar.bz2
# Removed urllib3-1.26.3-pyhd8ed1ab_0.tar.bz2
# Removed prompt-toolkit-3.0.14-pyha770c72_0.tar.bz2
# Removed traitlets-5.0.5-py_0.tar.bz2
# Removed gcsfs-0.7.1-py_0.tar.bz2
# Removed dask-ml-1.8.0-pyhd8ed1ab_0.tar.bz2
# Removed pycparser-2.20-pyh9f0ad1d_2.tar.bz2
# Removed pandocfilters-1.4.2-py_1.tar.bz2
# Removed openssl-1.1.1i-h7f98852_0.tar.bz2
# Removed ipykernel-5.4.2-py38h81c977d_0.tar.bz2
# Removed pickleshare-0.7.5-py_1003.tar.bz2
# Removed xarray-0.16.2-pyhd8ed1ab_0.tar.bz2
# Removed monotonic-1.5-py_0.tar.bz2
# Removed google-auth-1.24.0-pyhd3deb0d_0.tar.bz2
# Removed numpy-1.20.0-py38h18fd61f_0.tar.bz2
# Removed python-dateutil-2.8.1-py_0.tar.bz2
# Removed attrs-20.3.0-pyhd3deb0d_0.tar.bz2
# Removed libstdcxx-ng-9.3.0-h6de172a_18.tar.bz2
# Removed readline-8.0-he28a2e2_2.tar.bz2
# Removed pyparsing-2.4.7-pyh9f0ad1d_0.tar.bz2
# Removed distributed-2021.1.1-py38h578d9bd_0.tar.bz2
# Removed nbclient-0.5.1-py_0.tar.bz2
# Removed toolz-0.11.1-py_0.tar.bz2
# Removed sniffio-1.2.0-py38h578d9bd_1.tar.bz2
# Removed sqlite-3.34.0-h74cdb3f_0.tar.bz2
# Removed webencodings-0.5.1-py_1.tar.bz2
# Removed cryptography-3.3.1-py38h2b97feb_1.tar.bz2
# Removed ipython-7.20.0-py38h81c977d_0.tar.bz2
# Removed sortedcontainers-2.3.0-pyhd8ed1ab_0.tar.bz2
# Removed backcall-0.2.0-pyh9f0ad1d_0.tar.bz2
# Removed dask-2021.1.1-pyhd8ed1ab_0.tar.bz2
# Removed libffi-3.2.1-he1b5a44_1007.tar.bz2
# Removed setuptools-49.6.0-py38h578d9bd_3.tar.bz2
# Removed typing-extensions-3.7.4.3-0.tar.bz2
# Removed tk-8.6.10-h21135ba_1.tar.bz2
# Removed importlib_metadata-3.4.0-hd8ed1ab_0.tar.bz2
# Removed nbclassic-0.2.6-pyhd8ed1ab_0.tar.bz2
# Removed s3fs-0.5.2-pyhd8ed1ab_0.tar.bz2
# Removed aioitertools-0.7.1-pyhd8ed1ab_0.tar.bz2
# Removed jupyterlab_pygments-0.1.2-pyh9f0ad1d_0.tar.bz2
# Removed idna-2.10-pyh9f0ad1d_0.tar.bz2
# Removed ptyprocess-0.7.0-pyhd3deb0d_0.tar.bz2
# Removed pysocks-1.7.1-py38h578d9bd_3.tar.bz2
# Removed s3transfer-0.3.4-pyhd8ed1ab_0.tar.bz2
# Removed dask-glm-0.2.0-py_1.tar.bz2
# Removed zstd-1.4.8-ha95c52a_1.tar.bz2
# Removed fasteners-0.14.1-py_3.tar.bz2
# Removed joblib-1.0.0-pyhd8ed1ab_0.tar.bz2
# Removed llvmlite-0.35.0-py38h4630a5e_1.tar.bz2
# Removed oauthlib-3.0.1-py_0.tar.bz2
# Removed libopenblas-0.3.12-pthreads_h4812303_1.tar.bz2
# Removed packaging-20.8-pyhd3deb0d_0.tar.bz2
# Removed yarl-1.6.3-py38h497a2fe_1.tar.bz2
# Removed zarr-2.6.1-pyhd8ed1ab_0.tar.bz2
# Removed bokeh-2.2.3-py38h578d9bd_0.tar.bz2
# Removed multipledispatch-0.6.0-py_0.tar.bz2
# Removed tornado-6.1-py38h497a2fe_1.tar.bz2
# Removed psutil-5.8.0-py38h497a2fe_1.tar.bz2
# Removed pandas-1.2.1-py38h51da96c_0.tar.bz2
# Removed json5-0.9.5-pyh9f0ad1d_0.tar.bz2
# Removed prometheus_client-0.9.0-pyhd3deb0d_0.tar.bz2
# Removed jupyterlab_server-2.1.3-pyhd8ed1ab_0.tar.bz2
# Removed python-3.8.0-h357f687_5.tar.bz2
# Removed libgomp-9.3.0-h2828fa1_18.tar.bz2
# Removed dask-core-2021.1.1-pyhd8ed1ab_0.tar.bz2
# Removed jsonschema-3.2.0-py_2.tar.bz2
# Removed cachetools-4.2.1-pyhd8ed1ab_0.tar.bz2
# Removed parso-0.8.1-pyhd8ed1ab_0.tar.bz2
# Removed libwebp-base-1.2.0-h7f98852_0.tar.bz2
# Removed mistune-0.8.4-py38h497a2fe_1003.tar.bz2
# Removed pyyaml-5.4.1-py38h497a2fe_0.tar.bz2
# Removed coiled-0.0.35-pyhd8ed1ab_0.tar.bz2
# Removed click-7.1.2-pyh9f0ad1d_0.tar.bz2
# Removed msgpack-python-1.0.2-py38h1fd1430_1.tar.bz2
# Removed zlib-1.2.11-h516909a_1010.tar.bz2
# Removed pexpect-4.8.0-pyh9f0ad1d_2.tar.bz2
# Removed aiohttp-3.7.3-py38h497a2fe_1.tar.bz2
# Removed brotlipy-0.7.0-py38h497a2fe_1001.tar.bz2
# Removed fsspec-0.8.5-pyhd8ed1ab_0.tar.bz2
# Removed send2trash-1.5.0-py_0.tar.bz2
# Removed jupyterlab-3.0.6-pyhd8ed1ab_0.tar.bz2
# Removed nest-asyncio-1.4.3-pyhd8ed1ab_0.tar.bz2
# Removed tblib-1.6.0-py_0.tar.bz2
# Removed xz-5.2.5-h516909a_1.tar.bz2
# Removed nbformat-5.1.2-pyhd8ed1ab_1.tar.bz2
# Removed jpeg-9d-h36c2ea0_0.tar.bz2
# Removed python_abi-3.8-1_cp38.tar.bz2
# Removed requests-2.25.1-pyhd3deb0d_0.tar.bz2
# Removed scipy-1.6.0-py38hb2138dd_0.tar.bz2
# Removed jupyter_client-6.1.11-pyhd8ed1ab_1.tar.bz2
# Removed terminado-0.9.2-py38h578d9bd_0.tar.bz2
# Removed backports-1.0-py_2.tar.bz2
# Removed pytz-2021.1-pyhd8ed1ab_0.tar.bz2
# Removed pyzmq-22.0.1-py38h3d7ac18_0.tar.bz2
# Removed decorator-4.4.2-py_0.tar.bz2
# Removed lcms2-2.11-hcbb858e_1.tar.bz2
# Removed markupsafe-1.1.1-py38h497a2fe_3.tar.bz2
# Removed threadpoolctl-2.1.0-pyh5ca1d4c_0.tar.bz2
# Removed heapdict-1.0.1-py_0.tar.bz2
# Removed locket-0.2.0-py_2.tar.bz2
# Removed _openmp_mutex-4.5-1_gnu.tar.bz2
# Removed babel-2.9.0-pyhd3deb0d_0.tar.bz2
# Removed pyasn1-modules-0.2.7-py_0.tar.bz2
# Removed pandoc-2.11.4-h7f98852_0.tar.bz2
# Removed freetype-2.10.4-h0708190_1.tar.bz2
# Removed libcblas-3.9.0-7_openblas.tar.bz2
# Removed zeromq-4.3.3-h58526e2_3.tar.bz2
# Removed importlib-metadata-3.4.0-py38h578d9bd_0.tar.bz2
# Removed jmespath-0.10.0-pyh9f0ad1d_0.tar.bz2
# Removed botocore-1.19.52-pyhd8ed1ab_0.tar.bz2
# Removed _libgcc_mutex-0.1-conda_forge.tar.bz2
# Removed pillow-8.1.0-py38h357d4e7_1.tar.bz2
# Removed asciitree-0.3.3-py_2.tar.bz2
# Removed aiobotocore-1.2.0-pyhd8ed1ab_0.tar.bz2
# Removed nbconvert-6.0.7-py38h578d9bd_3.tar.bz2
# Removed argon2-cffi-20.1.0-py38h497a2fe_2.tar.bz2
# Removed wheel-0.36.2-pyhd3deb0d_0.tar.bz2
# Removed google-auth-oauthlib-0.4.2-pyhd8ed1ab_0.tar.bz2
# Removed scikit-learn-0.24.1-py38h658cfdd_0.tar.bz2
# Removed notebook-6.2.0-py38h578d9bd_0.tar.bz2
# Removed ca-certificates-2020.12.5-ha878542_0.tar.bz2
# Removed ncurses-6.2-h58526e2_4.tar.bz2
# Removed olefile-0.46-pyh9f0ad1d_1.tar.bz2
# Removed numcodecs-0.7.3-py38h709712a_0.tar.bz2
# Removed entrypoints-0.3-pyhd8ed1ab_1003.tar.bz2
# Removed defusedxml-0.6.0-py_0.tar.bz2
# Removed ipython_genutils-0.2.0-py_1.tar.bz2
# Removed jinja2-2.11.3-pyh44b312d_0.tar.bz2
# Removed numba-0.52.0-py38h51da96c_0.tar.bz2
# Removed pip-21.0.1-pyhd8ed1ab_0.tar.bz2
# Removed pygments-2.7.4-pyhd8ed1ab_0.tar.bz2
# Removed anyio-2.0.2-py38h578d9bd_4.tar.bz2
# Removed boto3-1.16.52-pyhd8ed1ab_0.tar.bz2
# Removed cffi-1.14.4-py38ha312104_0.tar.bz2
# Removed cytoolz-0.11.0-py38h497a2fe_3.tar.bz2
# Removed yaml-0.2.5-h516909a_0.tar.bz2
# Removed testpath-0.4.4-py_0.tar.bz2
# Removed wrapt-1.12.1-py38h497a2fe_3.tar.bz2
# Removed zict-2.0.0-py_0.tar.bz2
# Removed pyjwt-2.0.1-pyhd8ed1ab_0.tar.bz2
# Removed jupyter_server-1.2.2-py38h578d9bd_1.tar.bz2
# Removed liblapack-3.9.0-7_openblas.tar.bz2
# Removed libtiff-4.2.0-hdc55705_0.tar.bz2
# Removed libgfortran5-9.3.0-hff62375_18.tar.bz2
# Removed ld_impl_linux-64-2.35.1-hea4e1c9_2.tar.bz2
# Removed libpng-1.6.37-h21135ba_2.tar.bz2
# Removed blinker-1.4-py_1.tar.bz2
# Removed pyrsistent-0.17.3-py38h497a2fe_2.tar.bz2
# Removed libblas-3.9.0-7_openblas.tar.bz2
# Removed requests-oauthlib-1.3.0-pyh9f0ad1d_0.tar.bz2
# Removed wcwidth-0.2.5-pyh9f0ad1d_2.tar.bz2
# Removed libgcc-ng-9.3.0-h2828fa1_18.tar.bz2
# Removed pyasn1-0.4.8-py_0.tar.bz2
# Removed jedi-0.18.0-py38h578d9bd_2.tar.bz2
# Removed libllvm10-10.0.1-he513fc3_3.tar.bz2
# Removed lz4-c-1.9.3-h9c3ff4c_0.tar.bz2
# Removed jupyter_core-4.7.1-py38h578d9bd_0.tar.bz2
# Removed backports.functools_lru_cache-1.6.1-py_0.tar.bz2
# Removed async_generator-1.10-py_0.tar.bz2
# WARNING: /root/.conda/pkgs does not exist
# Cache location: /opt/conda/pkgs
# Will remove the following packages:
# /opt/conda/pkgs
# ---------------
#
# libgfortran-ng-9.3.0-hff62375_18              92 KB
# dask-2021.1.1-pyhd8ed1ab_0                    12 KB
# typing-extensions-3.7.4.3-0                   23 KB
# importlib_metadata-3.4.0-hd8ed1ab_0            9 KB
# python_abi-3.8-1_cp38                         10 KB
# _openmp_mutex-4.5-1_gnu                       93 KB
# libcblas-3.9.0-7_openblas                     41 KB
# _libgcc_mutex-0.1-conda_forge                  6 KB
# liblapack-3.9.0-7_openblas                    41 KB
# libblas-3.9.0-7_openblas                      41 KB
#
# ---------------------------------------------------
# Total:                                       368 KB
#
# removing libgfortran-ng-9.3.0-hff62375_18
# removing dask-2021.1.1-pyhd8ed1ab_0
# removing typing-extensions-3.7.4.3-0
# removing importlib_metadata-3.4.0-hd8ed1ab_0
# removing python_abi-3.8-1_cp38
# removing _openmp_mutex-4.5-1_gnu
# removing libcblas-3.9.0-7_openblas
# removing _libgcc_mutex-0.1-conda_forge
# removing liblapack-3.9.0-7_openblas
# removing libblas-3.9.0-7_openblas
# --> c9838544412
# STEP 4: ENV PATH /opt/conda/envs/coiled/bin:$PATH
# --> 835100119d1
# STEP 5: SHELL ["conda", "run", "-n", "coiled", "/bin/bash", "-c"]
# --> a5d0b83e20a
# STEP 6: COPY requirements.txt requirements.txt
# --> 7fc6df119a0
# STEP 7: RUN pip install -r requirements.txt     && rm requirements.txt
# Collecting git+https://****@github.com/aktech/sgkit.git@pairwise-comparison-clean (from -r requirements.txt (line 1))
# Cloning https://****@github.com/aktech/sgkit.git (to revision pairwise-comparison-clean) to /tmp/pip-req-build-s8kywtxt
# Requirement already satisfied: numpy in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.20.0)
# Requirement already satisfied: xarray in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.16.2)
# Collecting dask[array]==2.30.0
# Downloading dask-2.30.0-py3-none-any.whl (848 kB)
# Requirement already satisfied: dask-ml in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: scipy in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: zarr in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: numba in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.52.0)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: fsspec in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.8.5)
# Requirement already satisfied: setuptools>=41.2 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (49.6.0.post20210108)
# Requirement already satisfied: pyyaml in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask[array]==2.30.0->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: toolz>=0.8.2 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask[array]==2.30.0->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.11.1)
# Requirement already satisfied: distributed>=2.4.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2021.1.1)
# Requirement already satisfied: dask[array,dataframe]>=2.4.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2021.1.1)
# Requirement already satisfied: scikit-learn>=0.23 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: multipledispatch>=0.4.9 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: dask-glm>=0.2.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: packaging in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (20.8)
# Requirement already satisfied: pandas>=0.24.2 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask-glm>=0.2.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.6.0)
# Collecting dask[array,dataframe]>=2.4.0
# Downloading dask-2021.1.0-py3-none-any.whl (889 kB)
# Downloading dask-2020.12.0-py3-none-any.whl (884 kB)
# Requirement already satisfied: partd>=0.3.10 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from dask[array]==2.30.0->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: psutil>=5.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (5.8.0)
# Collecting distributed>=2.4.0
# Downloading distributed-2021.1.0-py3-none-any.whl (671 kB)
# Downloading distributed-2020.12.0-py3-none-any.whl (669 kB)
# Downloading distributed-2.30.1-py3-none-any.whl (656 kB)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: zict>=0.1.3 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (6.1)
# Requirement already satisfied: click>=6.6 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: msgpack>=0.6.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: tblib>=1.6.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: six in /opt/conda/envs/coiled/lib/python3.8/site-packages (from multipledispatch>=0.4.9->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from pandas>=0.24.2->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from pandas>=0.24.2->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: locket in /opt/conda/envs/coiled/lib/python3.8/site-packages (from partd>=0.3.10->dask[array]==2.30.0->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from scikit-learn>=0.23->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from scikit-learn>=0.23->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: heapdict in /opt/conda/envs/coiled/lib/python3.8/site-packages (from zict>=0.1.3->distributed>=2.4.0->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: llvmlite<0.36,>=0.35.0 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from numba->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.35.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from packaging->dask-ml->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: fasteners in /opt/conda/envs/coiled/lib/python3.8/site-packages (from zarr->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: numcodecs>=0.6.4 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from zarr->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.7.3)
# Requirement already satisfied: asciitree in /opt/conda/envs/coiled/lib/python3.8/site-packages (from zarr->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (0.3.3)
# Requirement already satisfied: monotonic>=0.1 in /opt/conda/envs/coiled/lib/python3.8/site-packages (from fasteners->zarr->sgkit==0.1.dev380+g19ab798->-r requirements.txt (line 1)) (1.5)
# Building wheels for collected packages: sgkit
# Building wheel for sgkit (setup.py): started
# Building wheel for sgkit (setup.py): finished with status 'done'
# Created wheel for sgkit: filename=sgkit-0.1.dev380+g19ab798-py3-none-any.whl size=96635 sha256=e5fd236e0b36758229baa865167bf1ed7a148f8fd91594eb82d31714dfed79d2
# Stored in directory: /tmp/pip-ephem-wheel-cache-1btjfevm/wheels/9a/26/8b/85f7aedb039ea0bd7a183ca78f19ff8898225e2411eb9f080d
# Successfully built sgkit
# Installing collected packages: dask, distributed, sgkit
# Attempting uninstall: dask
# Found existing installation: dask 2021.1.1
# Uninstalling dask-2021.1.1:
# Successfully uninstalled dask-2021.1.1
# Attempting uninstall: distributed
# Found existing installation: distributed 2021.1.1
# Uninstalling distributed-2021.1.1:
# Successfully uninstalled distributed-2021.1.1
# Successfully installed dask-2.30.0 distributed-2.30.1 sgkit-0.1.dev380+g19ab798
#
# STEP 8: COMMIT e419060d-9297-4388-94a8-24fe24d800c4
# --> a5a7c9f4713
# a5a7c9f47139db889d150576bafbf79b990d35b3620d0817d927e79c59f28b31
# Running command git clone -q 'https://****@github.com/aktech/sgkit.git' /tmp/pip-req-build-s8kywtxt
# Running command git checkout -b pairwise-comparison-clean --track origin/pairwise-comparison-clean
# Switched to a new branch 'pairwise-comparison-clean'
# Branch 'pairwise-comparison-clean' set up to track remote branch 'pairwise-comparison-clean' from 'origin'.
#
# Docker build succeeded: e419060d-9297-4388-94a8-24fe24d800c4
# Uploading image
# Getting image source signatures
# Copying blob sha256:005be9208aa6394d92e06c904af4e880fb380fa02be0a8aaffab105c82dd0a62
# Copying blob sha256:f5600c6330da7bb112776ba067a32a9c20842d6ecc8ee3289f1a713b644092f8
# Copying blob sha256:73571478965aec06a47d046298c659c0829276bb627684ad4dcb56547f09b619
# Copying blob sha256:ccef4c047a7327e4984d8b4bb30979cd3d69b026174f48a92e8cc24ac622fe7e
# Copying blob sha256:7f6891850733eb234978a42cf8378d8774c254d3e72688ad18c3c257b4ea16be
# Copying blob sha256:0553ab4c463e8dd22931a5deb37e8014a18cde60d6be1337f4415de56649a947
# Copying blob sha256:dfef8986f350d2efb7dd633410dceac30543be620085d9819f42db7067f55f64
# Copying blob sha256:210699d989a19372fa2724a601dc1edb3cd8369b8e4361eb66a890981c0c6db2
# Copying config sha256:a5a7c9f47139db889d150576bafbf79b990d35b3620d0817d927e79c59f28b31
# Writing manifest to image destination
# Storing signatures
# Finished updating environment
# CPU times: user 322 ms, sys: 94.7 ms, total: 417 ms
# Wall time: 4min 56s

# %%
coiled.create_cluster_configuration(name=env_name, software=env_name, worker_cpu=4, worker_memory="16 GiB")

# %%
# %%time
cluster = coiled.Cluster(configuration=f"aktech/{env_name}", n_workers=50, worker_options={
    "nthreads": 4,
    "env": {
#         "OMP_NUM_THREADS": "2",
#         "OPENBLAS_NUM_THREADS": "1",
    },
    "memory_limit": "16 GB"
})

# cluster = coiled.Cluster(name="aktech-d9b704a3-c")
client = Client(cluster, timeout=30)
print('Dashboard:', client.dashboard_link)
# Out:
# Creating Cluster. This takes about a minute ...Checking environment images
# Valid environment image found
# Dashboard: http://ec2-18-191-29-206.us-east-2.compute.amazonaws.com:8787
# CPU times: user 176 ms, sys: 39.5 ms, total: 215 ms
# Wall time: 1min 35s

# %%
# def set_config(key, value):
#     dask.config.set({key: value})
#     return dask.config.get(key)

# client.run_on_scheduler(set_config, "distributed.comm.timeouts.connect", "60s")
# client.run(set_config, "distributed.comm.timeouts.connect", "60s")

# %%
store = fsspec.get_mapper('gs://ag1000g-release/phase2.AR1/variation/main/zarr/all/ag1000g.phase2.ar1')
callset_snps = zarr.open_consolidated(store=store)
gt = callset_snps['2R/calldata/GT']
# Out:
# /Users/aktech/anaconda3/envs/sgkit-coiled/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
gt_da = da.from_zarr(gt)
x = gt_da[:, :, 1].T
x = x.rechunk((-1, 100000))
x
z = x[:100]
z
# Out:
# dask.array<getitem, shape=(100, 24767689), dtype=int8, chunksize=(100, 100000), chunktype=numpy.ndarray>

# %%
out_blockwise = pairwise_distance_blockwise(z, metric="correlation")
out_blocks = pairwise_distance_blocks(z, metric="correlation")

# %%
# %%time
with performance_report(filename="dask-report-pairwise_distance_blockwise.html"), get_task_stream(plot='save', filename="task-stream-pairwise_distance_blockwise.html") as ts:
    r1 = out_blockwise.compute()
# Out:
# CPU times: user 1.11 s, sys: 92 ms, total: 1.21 s
# Wall time: 1min 6s

# %%
# %%time
with performance_report(filename="dask-report-pairwise_distance_blocks.html"), get_task_stream(plot='save', filename="task-stream-pairwise_distance_blocks.html") as ts:
    r2 = out_blocks.compute()
# Out:
# CPU times: user 1.44 s, sys: 78.6 ms, total: 1.52 s
# Wall time: 57.7 s
